# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
doc = cv2.cvtColor(cv2.imread("../forms/Adult-Medical-Form.png"), cv2.COLOR_BGR2GRAY)

WIDTH = doc.shape[1]
HEIGHT = doc.shape[0]
IMAGE_SCALE = 0.01

plt.figure(figsize=(WIDTH*IMAGE_SCALE, HEIGHT*IMAGE_SCALE))
plt.imshow(doc, cmap='gray', vmin=0, vmax=255)
plt.axis('off')
# Out:
# (-0.5, 1699.5, 2799.5, -0.5)

# %%
# box corners: top-left, bot-left, bot-right, top-right
name_box = [[WIDTH]]
