# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pdf2image import convert_from_path

# %%
doc = np.array(convert_from_path("../forms/Adult-medical-and-consent-form-Spanish.pdf")[0])
print(len(convert_from_path("../forms/Adult-medical-and-consent-form-Spanish.pdf")))


plt.imshow(doc, vmin=0, vmax=255)
plt.axis('off')
# Out:
# 3
# (-0.5, 1699.5, 2199.5, -0.5)

# %%
cv2.imwrite("../forms/Adult-medical-and-consent-form-Spanish.png", cv2.cvtColor(doc, cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
convert_from_path("fake.pdf")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Documents/random/LawsonForms/env/lib/python3.6/site-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path)
#     435         if "Pages" not in d:
# --> 436             raise ValueError
#     437
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PDFPageCountError                         Traceback (most recent call last)
# <ipython-input-3-68ca6a217cf6> in <module>
# ----> 1 convert_from_path("fake.pdf")
#
# ~/Documents/random/LawsonForms/env/lib/python3.6/site-packages/pdf2image/pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only, use_pdftocairo)
# ...
